# %% [markdown]
# <a href="https://colab.research.google.com/github/mrant23/Jaringan_Syaraf_Tiruan/blob/main/Tugas3_jst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import semua library yang dibutuhkan
import numpy as np  # Untuk operasi numerik
import matplotlib.pyplot as plt  # Untuk visualisasi
import seaborn as sns  # Untuk visualisasi tingkat tinggi
import tensorflow as tf  # Framework deep learning
from tensorflow.keras import datasets, layers, models  # Modul-modul inti Keras
from tensorflow.keras.utils import to_categorical  # Untuk mengubah label menjadi one-hot encoding
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay  # Untuk evaluasi model

# Set seed untuk reproduksibilitas hasil
np.random.seed(42)
tf.random.set_seed(42)

# Load dan preprocess dataset CIFAR-10
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalisasi data gambar ke rentang 0-1
train_images = train_images.astype("float32") / 255.0
test_images = test_images.astype("float32") / 255.0

# Ubah label menjadi one-hot encoding
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
def create_model(activation_function):
    """
    Creates and compiles a CNN model with the specified activation function.

    Args:
        activation_function: The activation function to use in the convolutional layers.

    Returns:
        A compiled CNN model.
    """

    model = models.Sequential([
        # Convolutional layers
        layers.Conv2D(32, (3, 3), activation=activation_function, input_shape=(32, 32, 3)),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation=activation_function),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation=activation_function),

        # Flatten layer
        layers.Flatten(),

        # Dense layers
        layers.Dense(64, activation=activation_function),
        layers.Dense(10, activation='softmax')  # Output layer with softmax activation
    ])

    # Compile the model
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# List of activation functions to compare
activation_functions = ['linear', 'sigmoid', 'tanh', 'relu', 'leaky_relu']
results = {}

# %%
# Daftar fungsi aktivasi yang akan diuji
activation_functions = ['linear', 'sigmoid', 'tanh', 'relu', 'leaky_relu']

# Loop untuk setiap fungsi aktivasi
for activation in activation_functions:
    print(f"Training model with activation: {activation}")

    # Buat model secara khusus untuk leaky relu
    if activation == 'leaky_relu':
        model = models.Sequential([
            layers.Conv2D(32, (3, 3), input_shape=(32, 32, 3)),
            layers.Activation(tf.keras.layers.LeakyReLU(alpha=0.1)),
            layers.MaxPooling2D((2, 2)),
            layers.Conv2D(64, (3, 3)),
            layers.Activation(tf.keras.layers.LeakyReLU(alpha=0.1)),
            layers.MaxPooling2D((2, 2)),
            layers.Conv2D(64, (3, 3)),
            layers.Activation(tf.keras.layers.LeakyReLU(alpha=0.1)),
            layers.Flatten(),
            layers.Dense(64),
            layers.Activation(tf.keras.layers.LeakyReLU(alpha=0.1)),
            layers.Dense(10, activation='softmax')
        ])
    # Buat model dengan fungsi create_model untuk fungsi aktivasi lainnya
    else:
        model = create_model(activation)

    # Kompilasi model
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Latih model
    history = model.fit(train_images, train_labels, epochs=10, batch_size=64, validation_split=0.2, verbose=2)

    # Evaluasi model pada data testing
    test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=0)
# Out:
# Training model with activation: linear
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 625/625 - 57s - 91ms/step - accuracy: 0.4688 - loss: 1.5048 - val_accuracy: 0.5571 - val_loss: 1.2802
# Epoch 2/10
# 625/625 - 54s - 86ms/step - accuracy: 0.5744 - loss: 1.2278 - val_accuracy: 0.5910 - val_loss: 1.1960
# Epoch 3/10
# 625/625 - 50s - 80ms/step - accuracy: 0.6051 - loss: 1.1443 - val_accuracy: 0.6040 - val_loss: 1.1569
# Epoch 4/10
# 625/625 - 83s - 133ms/step - accuracy: 0.6253 - loss: 1.0891 - val_accuracy: 0.6150 - val_loss: 1.1235
# Epoch 5/10
# 625/625 - 82s - 131ms/step - accuracy: 0.6406 - loss: 1.0440 - val_accuracy: 0.6211 - val_loss: 1.1181
# Epoch 6/10
# 625/625 - 51s - 81ms/step - accuracy: 0.6543 - loss: 1.0041 - val_accuracy: 0.6246 - val_loss: 1.1091
# Epoch 7/10
# 625/625 - 85s - 136ms/step - accuracy: 0.6670 - loss: 0.9687 - val_accuracy: 0.6251 - val_loss: 1.1067
# Epoch 8/10
# 625/625 - 50s - 80ms/step - accuracy: 0.6783 - loss: 0.9357 - val_accuracy: 0.6250 - val_loss: 1.1198
# Epoch 9/10
# 625/625 - 83s - 134ms/step - accuracy: 0.6884 - loss: 0.9059 - val_accuracy: 0.6213 - val_loss: 1.1348
# Epoch 10/10
# 625/625 - 82s - 131ms/step - accuracy: 0.6988 - loss: 0.8782 - val_accuracy: 0.6198 - val_loss: 1.1572
# Training model with activation: sigmoid
# Epoch 1/10
# 625/625 - 56s - 90ms/step - accuracy: 0.1934 - loss: 2.1372 - val_accuracy: 0.2732 - val_loss: 1.9691
# Epoch 2/10
# 625/625 - 82s - 131ms/step - accuracy: 0.3014 - loss: 1.9026 - val_accuracy: 0.3382 - val_loss: 1.8246
# Epoch 3/10
# 625/625 - 82s - 132ms/step - accuracy: 0.3719 - loss: 1.7411 - val_accuracy: 0.3982 - val_loss: 1.6870
# Epoch 4/10
# 625/625 - 81s - 130ms/step - accuracy: 0.4166 - loss: 1.6329 - val_accuracy: 0.4234 - val_loss: 1.6126
# Epoch 5/10
# 625/625 - 85s - 136ms/step - accuracy: 0.4414 - loss: 1.5632 - val_accuracy: 0.4495 - val_loss: 1.5526
# Epoch 6/10
# 625/625 - 79s - 127ms/step - accuracy: 0.4645 - loss: 1.5033 - val_accuracy: 0.4674 - val_loss: 1.5006
# Epoch 7/10
# 625/625 - 65s - 104ms/step - accuracy: 0.4818 - loss: 1.4523 - val_accuracy: 0.4796 - val_loss: 1.4610
# Epoch 8/10
# 625/625 - 72s - 116ms/step - accuracy: 0.4973 - loss: 1.4101 - val_accuracy: 0.4907 - val_loss: 1.4299
# Epoch 9/10
# 625/625 - 81s - 129ms/step - accuracy: 0.5116 - loss: 1.3720 - val_accuracy: 0.5003 - val_loss: 1.4046
# Epoch 10/10
# 625/625 - 82s - 131ms/step - accuracy: 0.5238 - loss: 1.3367 - val_accuracy: 0.5064 - val_loss: 1.3832
# Training model with activation: tanh
# Epoch 1/10
# 625/625 - 57s - 91ms/step - accuracy: 0.4598 - loss: 1.5159 - val_accuracy: 0.5546 - val_loss: 1.2571
# Epoch 2/10
# 625/625 - 55s - 88ms/step - accuracy: 0.5814 - loss: 1.1924 - val_accuracy: 0.5997 - val_loss: 1.1438
# Epoch 3/10
# 625/625 - 84s - 135ms/step - accuracy: 0.6258 - loss: 1.0717 - val_accuracy: 0.6164 - val_loss: 1.0988
# Epoch 4/10
# 625/625 - 79s - 127ms/step - accuracy: 0.6542 - loss: 0.9959 - val_accuracy: 0.6279 - val_loss: 1.0739
# Epoch 5/10
# 625/625 - 82s - 132ms/step - accuracy: 0.6738 - loss: 0.9397 - val_accuracy: 0.6340 - val_loss: 1.0661
# Epoch 6/10
# 625/625 - 82s - 131ms/step - accuracy: 0.6930 - loss: 0.8894 - val_accuracy: 0.6310 - val_loss: 1.0819
# Epoch 7/10
# 625/625 - 82s - 131ms/step - accuracy: 0.7083 - loss: 0.8471 - val_accuracy: 0.6212 - val_loss: 1.1217
# Epoch 8/10
# 625/625 - 81s - 129ms/step - accuracy: 0.7259 - loss: 0.8017 - val_accuracy: 0.6207 - val_loss: 1.1260
# Epoch 9/10
# 625/625 - 83s - 133ms/step - accuracy: 0.7391 - loss: 0.7614 - val_accuracy: 0.6253 - val_loss: 1.1175
# Epoch 10/10
# 625/625 - 82s - 131ms/step - accuracy: 0.7500 - loss: 0.7304 - val_accuracy: 0.6289 - val_loss: 1.1175
# Training model with activation: relu
# Epoch 1/10
# 625/625 - 53s - 85ms/step - accuracy: 0.3819 - loss: 1.6718 - val_accuracy: 0.5051 - val_loss: 1.3881
# Epoch 2/10
# 625/625 - 84s - 134ms/step - accuracy: 0.5203 - loss: 1.3307 - val_accuracy: 0.5486 - val_loss: 1.2627
# Epoch 3/10
# 625/625 - 82s - 131ms/step - accuracy: 0.5785 - loss: 1.1795 - val_accuracy: 0.5935 - val_loss: 1.1508
# Epoch 4/10
# 625/625 - 82s - 131ms/step - accuracy: 0.6198 - loss: 1.0743 - val_accuracy: 0.6227 - val_loss: 1.0657
# Epoch 5/10
# 625/625 - 82s - 131ms/step - accuracy: 0.6479 - loss: 0.9976 - val_accuracy: 0.6422 - val_loss: 1.0223
# Epoch 6/10
# 625/625 - 81s - 129ms/step - accuracy: 0.6730 - loss: 0.9322 - val_accuracy: 0.6514 - val_loss: 1.0027
# Epoch 7/10
# 625/625 - 52s - 83ms/step - accuracy: 0.6948 - loss: 0.8757 - val_accuracy: 0.6619 - val_loss: 0.9704
# Epoch 8/10
# 625/625 - 82s - 131ms/step - accuracy: 0.7102 - loss: 0.8292 - val_accuracy: 0.6708 - val_loss: 0.9673
# Epoch 9/10
# 625/625 - 81s - 130ms/step - accuracy: 0.7256 - loss: 0.7868 - val_accuracy: 0.6711 - val_loss: 0.9669
# Epoch 10/10
# 625/625 - 81s - 129ms/step - accuracy: 0.7380 - loss: 0.7513 - val_accuracy: 0.6709 - val_loss: 0.9911
# Training model with activation: leaky_relu
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/10
# 625/625 - 56s - 90ms/step - accuracy: 0.4306 - loss: 1.5565 - val_accuracy: 0.5582 - val_loss: 1.2593
# Epoch 2/10
# 625/625 - 81s - 129ms/step - accuracy: 0.5880 - loss: 1.1602 - val_accuracy: 0.6229 - val_loss: 1.0774
# Epoch 3/10
# 625/625 - 81s - 129ms/step - accuracy: 0.6503 - loss: 0.9950 - val_accuracy: 0.6565 - val_loss: 0.9865
# Epoch 4/10
# 625/625 - 83s - 133ms/step - accuracy: 0.6869 - loss: 0.8855 - val_accuracy: 0.6737 - val_loss: 0.9401
# Epoch 5/10
# 625/625 - 82s - 131ms/step - accuracy: 0.7187 - loss: 0.8022 - val_accuracy: 0.6836 - val_loss: 0.9138
# Epoch 6/10
# 625/625 - 83s - 132ms/step - accuracy: 0.7434 - loss: 0.7339 - val_accuracy: 0.6915 - val_loss: 0.9042
# Epoch 7/10
# 625/625 - 82s - 131ms/step - accuracy: 0.7661 - loss: 0.6729 - val_accuracy: 0.6956 - val_loss: 0.9080
# Epoch 8/10
# 625/625 - 81s - 130ms/step - accuracy: 0.7865 - loss: 0.6197 - val_accuracy: 0.6937 - val_loss: 0.9514
# Epoch 9/10
# 625/625 - 82s - 131ms/step - accuracy: 0.7996 - loss: 0.5749 - val_accuracy: 0.6929 - val_loss: 0.9780
# Epoch 10/10
# 625/625 - 82s - 131ms/step - accuracy: 0.8152 - loss: 0.5283 - val_accuracy: 0.6964 - val_loss: 1.0034

# %%
# Simpan hasil pelatihan, evaluasi, dan matriks konfusi
y_pred = model.predict(test_images)  # Lakukan prediksi pada data testing
y_pred_classes = np.argmax(y_pred, axis=1)  # Ambil kelas dengan probabilitas tertinggi dari prediksi
y_true = np.argmax(test_labels, axis=1)  # Ambil kelas sebenarnya dari label testing
conf_matrix = confusion_matrix(y_true, y_pred_classes)  # Hitung matriks konfusi

# Simpan hasil ke dalam dictionary results
results[activation] = (history, test_loss, test_acc, conf_matrix)

# Plot hasil akurasi dan loss
plt.figure(figsize=(16, 6))  # Buat figure dengan ukuran 16x6

# Plot akurasi pelatihan
plt.subplot(1, 2, 1)  # Buat subplot pertama (1 baris, 2 kolom, posisi 1)
for activation, (history, _, _, _) in results.items():
    plt.plot(history.history['accuracy'], label=f'{activation} (train)')  # Plot akurasi pelatihan untuk setiap fungsi aktivasi
plt.title('Training Accuracy for Different Activation Functions on CIFAR-10')  # Beri judul plot
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step
# Text(0.5, 1.0, 'Training Accuracy for Different Activation Functions on CIFAR-10')

# %%
# Plot training loss
plt.subplot(1, 2, 2)  # Buat subplot kedua (1 baris, 2 kolom, posisi 2)
for activation, (history, _, _, _) in results.items():
    plt.plot(history.history['loss'], label=f'{activation} (train)')  # Plot loss pelatihan untuk setiap fungsi aktivasi
plt.title('Training Loss for Different Activation Functions on CIFAR-10')  # Beri judul plot
plt.ylabel('Loss')  # Beri label sumbu y
plt.xlabel('Epoch')  # Beri label sumbu x
plt.legend()  # Tampilkan legenda
plt.grid(True)  # Tampilkan grid
plt.show()  # Tampilkan plot

# Display confusion matrix for each activation function
for activation, (_, _, test_acc, conf_matrix) in results.items():
    print(f'\nTest accuracy with {activation}: {test_acc:.4f}')  # Cetak akurasi testing

    plt.figure(figsize=(8, 6))  # Buat figure baru untuk matriks konfusi
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                xticklabels=[f'Class {i}' for i in range(10)],  # Label sumbu x
                yticklabels=[f'Class {i}' for i in range(10)])  # Label sumbu y
    plt.title(f'Confusion Matrix for {activation.capitalize()} Activation on CIFAR-10')  # Beri judul plot
    plt.xlabel('Predicted Labels')  # Label sumbu x
    plt.ylabel('True Labels')  # Label sumbu y
    plt.show()  # Tampilkan plot
# Out:
# Test accuracy with leaky_relu: 0.6918
